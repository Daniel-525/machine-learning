# %% [markdown]
# <p align="center">
#
# ![Logo ITQ](img/logoitqv1.jpg)
#
# </p>
#
# ## 01PAO26-26 - Variables cualitativas
#
# <p align="center">
#
# ![logo python](img/python_logo.png)
#
# </p>
#
# *Cristian Daniel Arias Ipiales*
#
# **[REPOSITORIO](https://github.com/Daniel-525/machine-learning/blob/main/PAO25_25_02_Python_Datatype.ipynb)**

# %%
# Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)
nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Doctorado'
#  'Secundaria' 'Grado' 'Secundaria' 'Secundaria' 'Grado' 'Bachillerato'
#  'Master' 'Master' 'Grado' 'Grado' 'Master' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Secundaria' 'Bachillerato' 'Secundaria' 'Master' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Secundaria'
#  'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Master' 'Bachillerato' 'Grado' 'Grado' 'Grado'
#  'Secundaria' 'Grado' 'Grado' 'Grado' 'Secundaria' 'Master' 'Secundaria'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Master' 'Secundaria'
#  'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Master' 'Grado' 'Secundaria' 'Grado' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Secundaria'
#  'Bachillerato' 'Master' 'Grado' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Secundaria' 'Grado' 'Bachillerato' 'Master' 'Doctorado' 'Master'
#  'Bachillerato' 'Grado' 'Master' 'Grado' 'Secundaria' 'Doctorado' 'Grado'
#  'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Doctorado'
#  'Bachillerato' 'Master' 'Grado' 'Bachillerato' 'Grado' 'Secundaria'
#  'Secundaria' 'Doctorado' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Master' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Master'
#  'Grado' 'Grado' 'Grado' 'Master' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Doctorado' 'Secundaria' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Doctorado' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Doctorado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Grado' 'Grado' 'Secundaria' 'Doctorado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Master' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Secundaria' 'Doctorado' 'Grado' 'Secundaria' 'Master' 'Grado'
#  'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Secundaria'
#  'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Master' 'Bachillerato' 'Grado'
#  'Master' 'Doctorado' 'Bachillerato' 'Master' 'Master' 'Secundaria'
#  'Grado' 'Grado' 'Master' 'Grado' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Master' 'Secundaria'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado'
#  'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Master' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Doctorado' 'Master' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Doctorado' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Grado' 'Master' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Grado' 'Doctorado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Secundaria'
#  'Master' 'Grado' 'Bachillerato' 'Doctorado' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Master' 'Master' 'Grado'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Master' 'Bachillerato' 'Master' 'Bachillerato' 'Master' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Doctorado' 'Grado' 'Master' 'Grado'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Grado' 'Secundaria' 'Grado'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Doctorado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Master' 'Grado'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Master' 'Bachillerato'
#  'Bachillerato' 'Master' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Grado'
#  'Master' 'Grado' 'Grado' 'Secundaria' 'Secundaria' 'Grado' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Master' 'Bachillerato' 'Grado'
#  'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Master' 'Bachillerato' 'Master' 'Doctorado' 'Bachillerato' 'Secundaria'
#  'Master' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Secundaria' 'Master' 'Secundaria' 'Bachillerato' 'Doctorado'
#  'Secundaria' 'Bachillerato' 'Master' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Grado' 'Grado' 'Master' 'Secundaria' 'Master' 'Grado'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Master'
#  'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Doctorado' 'Grado'
#  'Secundaria' 'Secundaria' 'Grado' 'Bachillerato' 'Master' 'Grado'
#  'Doctorado' 'Grado' 'Bachillerato' 'Master' 'Master']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np

estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()

# %%
# Tarea implementar con pandas esta información
#Importamos pandas
import pandas as pd

serie_estudios = pd.Series(nivel_estudios)
serie_estudios.head()
# Out:
# 0           Grado
# 1           Grado
# 2    Bachillerato
# 3    Bachillerato
# 4    Bachillerato
# dtype: str

# %%
# Tabla de frecuencias con pandas
frecuencia_absoluta = serie_estudios.value_counts()
frecuencia_relativa = serie_estudios.value_counts(normalize=True)

tabla_frecuencias = pd.DataFrame({
    'Frecuencia absoluta': frecuencia_absoluta,
    'Frecuencia relativa': frecuencia_relativa,
    'Porcentaje (%)': frecuencia_relativa * 100
})

tabla_frecuencias
# Out:
#               Frecuencia absoluta  Frecuencia relativa  Porcentaje (%)
# Bachillerato                  172                0.344            34.4
# Grado                         145                0.290            29.0
# Secundaria                    110                0.220            22.0
# Master                         52                0.104            10.4
# Doctorado                      21                0.042             4.2

# %%
# Diagrama de barras usando el método .plot() de pandas
tabla_frecuencias['Frecuencia absoluta'].plot(kind='bar', ylabel='Frecuencia absoluta', xlabel='Nivel de estudios', title='Diagrama de barras (con pandas)')
plt.show()

# %%
# Diagrama de sectores usando el método .plot() de pandas
tabla_frecuencias['Frecuencia absoluta'].plot(kind='pie', autopct='%1.2f%%', ylabel='', title='Diagrama de sectores (con pandas)')
plt.show()
